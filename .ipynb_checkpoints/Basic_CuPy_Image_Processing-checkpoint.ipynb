# %% [markdown]
# Install needed packages

# %% [markdown]
# currently use a bruteforce method
#
# ln -s /usr/local/cuda/lib64/libnvrtc-builtins.so.10.0.130 /usr/local/EMAN2/lib/libnvrtc-builtins.so

# %%
# !pip install pillow
# !pip install numpy
# if system has CUDA 10.1, install cupy-cuda101
# !pip install cupy-cuda100
# Out:
# DEPRECATION: Python 2.7 will reach the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 won't be maintained after that date. A future version of pip will drop support for Python 2.7. More details about Python 2 support in pip, can be found at https://pip.pypa.io/en/latest/development/release-process/#python-2-support
# Requirement already satisfied: pillow in /home/phonchi30/.local/lib/python2.7/site-packages (6.2.2)
# DEPRECATION: Python 2.7 will reach the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 won't be maintained after that date. A future version of pip will drop support for Python 2.7. More details about Python 2 support in pip, can be found at https://pip.pypa.io/en/latest/development/release-process/#python-2-support
# Requirement already satisfied: numpy in /home/phonchi30/.local/lib/python2.7/site-packages (1.16.6)
# DEPRECATION: Python 2.7 will reach the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 won't be maintained after that date. A future version of pip will drop support for Python 2.7. More details about Python 2 support in pip, can be found at https://pip.pypa.io/en/latest/development/release-process/#python-2-support
# Collecting cupy-cuda100
#   Using cached https://files.pythonhosted.org/packages/e1/1b/3045af1610fe3ac86434262d6e3e6fc15f3ce447b87d077ffd75e83a9f4b/cupy_cuda100-6.7.0-cp27-cp27mu-manylinux1_x86_64.whl
# Requirement already satisfied: fastrlock>=0.3 in /home/phonchi30/.local/lib/python2.7/site-packages (from cupy-cuda100) (0.5)
# Requirement already satisfied: numpy>=1.9.0 in /home/phonchi30/.local/lib/python2.7/site-packages (from cupy-cuda100) (1.16.6)
# Requirement already satisfied: six>=1.9.0 in /home/phonchi30/.local/lib/python2.7/site-packages (from cupy-cuda100) (1.15.0)
# Installing collected packages: cupy-cuda100
# Successfully installed cupy-cuda100-6.7.0

# %% [markdown]
# Load an image

# %%
import sys
sys.path.insert(0, "/usr/local/cuda/lib64")
from PIL import Image
logo_img = Image.open('logo.png')

from IPython.display import display
display(logo_img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=267x267 at 0x7F87B8155210>

# %% [markdown]
# Convert image to RGB map, RGBRGBRGB... -> RRR...RGGG...GBBB...B
#
# Convert RGB map to numpy array, then convert numpy array to cupy array

# %%
(r, g, b) = logo_img.split()
import numpy as np
r_array = np.array(r)
g_array = np.array(g)
b_array = np.array(b)
logo_array = np.stack((r_array, g_array, b_array))

# %%
import cupy as cp
in_gpu_array = cp.array(logo_array)
out_gpu_array = cp.empty_like(in_gpu_array)

# %%
cp.__version__
# Out:
# '6.7.0'

# %%
import os
os.environ['LD_LIBRARY_PATH']='/usr/local/cuda/lib64:'+os.environ['LD_LIBRARY_PATH']

# %%
os.environ['CUDA_PATH']='/usr/local/cuda'

# %%
# %env
# Out:
# {'BAZELRC': '/home/phonchi30/.bazelrc',
#  'CLICOLOR': '1',
#  'CONDA_DEFAULT_ENV': 'base',
#  'CONDA_EXE': '/usr/local/EMAN2/bin/conda',
#  'CONDA_PREFIX': '/usr/local/EMAN2',
#  'CONDA_PROMPT_MODIFIER': '(base) ',
#  'CONDA_PYTHON_EXE': '/usr/local/EMAN2/bin/python',
#  'CONDA_SHLVL': '1',
#  'CREATOR_ACCOUNT': 'phonchi30',
#  'CUDA_PATH': '/usr/local/cuda',
#  'CUDA_PKG_VERSION': '10-0=10.0.130-1',
#  'CUDA_VERSION': '10.0.130',
#  'CUDNN_VERSION': '7.6.5.32',
#  'GIT_PAGER': 'cat',
#  'HAZC3FCTR1601451635425_PORT': 'tcp://10.104.249.46:50635',
#  'HAZC3FCTR1601451635425_PORT_50635_TCP': 'tcp://10.104.249.46:50635',
#  'HAZC3FCTR1601451635425_PORT_50635_TCP_ADDR': '10.104.249.46',
#  'HAZC3FCTR1601451635425_PORT_50635_TCP_PORT': '50635',
#  'HAZC3FCTR1601451635425_PORT_50635_TCP_PROTO': 'tcp',
#  'HAZC3FCTR1601451635425_PORT_51747_TCP': 'tcp://10.104.249.46:51747',
#  'HAZC3FCTR1601451635425_PORT_51747_TCP_ADDR': '10.104.249.46',
#  'HAZC3FCTR1601451635425_PORT_51747_TCP_PORT': '51747',
#  'HAZC3FCTR1601451635425_PORT_51747_TCP_PROTO': 'tcp',
#  'HAZC3FCTR1601451635425_SERVICE_HOST': '10.104.249.46',
#  'HAZC3FCTR1601451635425_SERVICE_PORT': '50635',
#  'HAZC3FCTR1601451635425_SERVICE_PORT_AX0KK0CTR1601451635425': '51747',
#  'HAZC3FCTR1601451635425_SERVICE_PORT_FZ9JXPCTR1601451635425': '50635',
#  'HOME': '/home/phonchi30',
#  'HOSTNAME': 'mpdiwsctr1601451635425-ttc2f',
#  'JPY_PARENT_PID': '66',
#  'KUBERNETES_PORT': 'tcp://10.96.0.1:443',
#  'KUBERNETES_PORT_443_TCP': 'tcp://10.96.0.1:443',
#  'KUBERNETES_PORT_443_TCP_ADDR': '10.96.0.1',
#  'KUBERNETES_PORT_443_TCP_PORT': '443',
#  'KUBERNETES_PORT_443_TCP_PROTO': 'tcp',
#  'KUBERNETES_SERVICE_HOST': '10.96.0.1',
#  'KUBERNETES_SERVICE_PORT': '443',
#  'KUBERNETES_SERVICE_PORT_HTTPS': '443',
#  'KUYZNCCTR1601974138862_PORT': 'tcp://10.101.219.88:51597',
#  'KUYZNCCTR1601974138862_PORT_51597_TCP': 'tcp://10.101.219.88:51597',
#  'KUYZNCCTR1601974138862_PORT_51597_TCP_ADDR': '10.101.219.88',
#  'KUYZNCCTR1601974138862_PORT_51597_TCP_PORT': '51597',
#  'KUYZNCCTR1601974138862_PORT_51597_TCP_PROTO': 'tcp',
#  'KUYZNCCTR1601974138862_PORT_51893_TCP': 'tcp://10.101.219.88:51893',
#  'KUYZNCCTR1601974138862_PORT_51893_TCP_ADDR': '10.101.219.88',
#  'KUYZNCCTR1601974138862_PORT_51893_TCP_PORT': '51893',
#  'KUYZNCCTR1601974138862_PORT_51893_TCP_PROTO': 'tcp',
#  'KUYZNCCTR1601974138862_SERVICE_HOST': '10.101.219.88',
#  'KUYZNCCTR1601974138862_SERVICE_PORT': '51597',
#  'KUYZNCCTR1601974138862_SERVICE_PORT_CF59FPCTR1601974138862': '51597',
#  'KUYZNCCTR1601974138862_SERVICE_PORT_E2NP3ACTR1601974138862': '51893',
#  'LD_LIBRARY_PATH': '/usr/local/cuda/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64',
#  'LIBRARY_PATH': '/usr/local/cuda/lib64/stubs',
#  'LOGNAME': 'phonchi30',
#  'MAIL': '/var/mail/phonchi30',
#  'MPLBACKEND': 'module://ipykernel.pylab.backend_inline',
#  'NCCL_VERSION': '2.5.6',
#  'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility',
#  'NVIDIA_REQUIRE_CUDA': 'cuda>=10.0 brand=tesla,driver>=384,driver<385 brand=tesla,driver>=410,driver<411',
#  'NVIDIA_VISIBLE_DEVICES': 'GPU-e1497c3a-80e8-a72b-531c-5bec4174858b',
#  'PAGER': 'cat',
#  'PATH': '/usr/local/EMAN2/bin:/usr/local/EMAN2/condabin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/home/phonchi30/.local/bin:/home/phonchi30/.local/bin:/home/phonchi30/bin',
#  'PWD': '/home/phonchi30',
#  'SHELL': '/bin/bash',
#  'SHLVL': '2',
#  'SUDO_COMMAND': '/bin/bash -c /run_jupyter.sh --port=8888 --notebook-dir=/home/phonchi30 --config=/etc/jupyter/jupyter_notebook_config.py',
#  'SUDO_GID': '43059',
#  'SUDO_UID': '19453',
#  'SUDO_USER': 'phonchi30',
#  'TERM': 'xterm-color',
#  'USER': 'phonchi30',
#  'USERNAME': 'phonchi30',
#  'WYO8EXCTR1600926756998_PORT': 'tcp://10.100.164.188:54538',
#  'WYO8EXCTR1600926756998_PORT_54538_TCP': 'tcp://10.100.164.188:54538',
#  'WYO8EXCTR1600926756998_PORT_54538_TCP_ADDR': '10.100.164.188',
#  'WYO8EXCTR1600926756998_PORT_54538_TCP_PORT': '54538',
#  'WYO8EXCTR1600926756998_PORT_54538_TCP_PROTO': 'tcp',
#  'WYO8EXCTR1600926756998_PORT_54922_TCP': 'tcp://10.100.164.188:54922',
#  'WYO8EXCTR1600926756998_PORT_54922_TCP_ADDR': '10.100.164.188',
#  'WYO8EXCTR1600926756998_PORT_54922_TCP_PORT': '54922',
#  'WYO8EXCTR1600926756998_PORT_54922_TCP_PROTO': 'tcp',
#  'WYO8EXCTR1600926756998_SERVICE_HOST': '10.100.164.188',
#  'WYO8EXCTR1600926756998_SERVICE_PORT': '54538',
#  'WYO8EXCTR1600926756998_SERVICE_PORT_R6Z3W0CTR1600926756998': '54922',
#  'WYO8EXCTR1600926756998_SERVICE_PORT_RP89J1CTR1600926756998': '54538',
#  'ZO0E1QCTR1600751323695_PORT': 'tcp://10.96.213.53:53903',
#  'ZO0E1QCTR1600751323695_PORT_53903_TCP': 'tcp://10.96.213.53:53903',
#  'ZO0E1QCTR1600751323695_PORT_53903_TCP_ADDR': '10.96.213.53',
#  'ZO0E1QCTR1600751323695_PORT_53903_TCP_PORT': '53903',
#  'ZO0E1QCTR1600751323695_PORT_53903_TCP_PROTO': 'tcp',
#  'ZO0E1QCTR1600751323695_PORT_59989_TCP': 'tcp://10.96.213.53:59989',
#  'ZO0E1QCTR1600751323695_PORT_59989_TCP_ADDR': '10.96.213.53',
#  'ZO0E1QCTR1600751323695_PORT_59989_TCP_PORT': '59989',
#  'ZO0E1QCTR1600751323695_PORT_59989_TCP_PROTO': 'tcp',
#  'ZO0E1QCTR1600751323695_SERVICE_HOST': '10.96.213.53',
#  'ZO0E1QCTR1600751323695_SERVICE_PORT': '53903',
#  'ZO0E1QCTR1600751323695_SERVICE_PORT_BIDMWVCTR1600751323695': '59989',
#  'ZO0E1QCTR1600751323695_SERVICE_PORT_N8TFQ1CTR1600751323695': '53903',
#  '_': '/usr/local/bin/jupyter',
#  '_CE_CONDA': '',
#  '_CE_M': '',
#  '_apihost': 'k8s-taichung-default',
#  '_project_code': 'ACD109084',
#  'site_id': '1241013'}

# %% [markdown]
# Implement GPU kernel via cupy.RawKernel

# %%
import sys
sys.path
# Out:
# ['/usr/local/cuda/lib64',
#  '',
#  '/usr/local/EMAN2/lib/python27.zip',
#  '/usr/local/EMAN2/lib/python2.7',
#  '/usr/local/EMAN2/lib/python2.7/plat-linux2',
#  '/usr/local/EMAN2/lib/python2.7/lib-tk',
#  '/usr/local/EMAN2/lib/python2.7/lib-old',
#  '/usr/local/EMAN2/lib/python2.7/lib-dynload',
#  '/home/phonchi30/.local/lib/python2.7/site-packages',
#  '/usr/local/EMAN2/lib/python2.7/site-packages',
#  '/usr/local/EMAN2/lib/python2.7/site-packages/IPython/extensions',
#  '/home/phonchi30/.ipython']

# %%
os.environ['PYTHONPATH']
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-12-8d2d88d7e1ea> in <module>()
# ----> 1 os.environ['PYTHONPATH']
#
# /usr/local/EMAN2/lib/python2.7/UserDict.pyc in __getitem__(self, key)
#      38         if hasattr(self.__class__, "__missing__"):
#      39             return self.__class__.__missing__(self, key)
# ---> 40         raise KeyError(key)
#      41     def __setitem__(self, key, item): self.data[key] = item
#      42     def __delitem__(self, key): del self.data[key]
#
# KeyError: 'PYTHONPATH'

# %%
from cupy.cuda import nvrtc
nvrtc.getVersion()
# Out:
# (10, 0)

# %%
img_add_const_value_kernel = cp.RawKernel(r'''
    extern "C" __global__
    void img_add_const_value(unsigned char* dst, unsigned char* src, int w, int h, int v) {
        int x = blockIdx.x * blockDim.x + threadIdx.x;
        int y = blockIdx.y * blockDim.y + threadIdx.y;
        int z = blockIdx.z * blockDim.z + threadIdx.z;
        if (x < w && y < h) {
            src += w * h * z;
            dst += w * h * z;
            int pos = y * w + x;
            int tmp = (int)src[pos] + v;
            tmp = (tmp > 255) ? 255:tmp;
            tmp = (tmp <   0) ?   0:tmp;
            dst[pos] = tmp;
        }
    }
    ''', 'img_add_const_value')

# %% [markdown]
# Declare needed grid, block size, and run the kernel

# %%
(c, h, w) = in_gpu_array.shape
block = (16, 16, 1)
grid = ((w + 15)//16, (h + 15)//16, c)
img_add_const_value_kernel(grid, block, (out_gpu_array, in_gpu_array, w, h, 50))

# %% [markdown]
# Convert cupy array to numpy array, then convert numpy array back to image

# %%
out_logo_array = cp.asnumpy(out_gpu_array)

r_img = Image.fromarray(out_logo_array[0,:,:])
g_img = Image.fromarray(out_logo_array[1,:,:])
b_img = Image.fromarray(out_logo_array[2,:,:])

out_img = Image.merge('RGB', (r_img, g_img, b_img))

# %% [markdown]
# Result

# %%
display(out_img)
# Out:
# <PIL.Image.Image image mode=RGB size=267x267 at 0x7F86F66F0790>

# %% [markdown]
# done
